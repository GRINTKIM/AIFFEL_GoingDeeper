# %% [markdown]
# # **ResNet** Ablation Study
# ***
# ***

# %% [markdown]
# #### Import Libraries

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend, regularizers, initializers, models

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Load Data

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

# %%
# Tensorflow 데이터셋을 로드하면 꼭 feature 정보를 확인해 보세요. 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })

# %%
# 데이터의 개수도 확인해 봅시다. 
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
ds_info.features["label"].num_classes
# Out:
# 2

# %%
ds_info.features["label"].names
# Out:
# ['cat', 'dog']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %% [markdown]
# ### Input Normalization

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, (224,224))
    image = tf.cast(image, tf.float32) / 255.
    return image, label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    #ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %% [markdown]
# ## 1) ResNet 기본 블록 구성하기
# ***

# %%
def conv_block(input_layer, 
               channel, 
               kernel_size, 
               strides=1, 
               activation='relu'):
    
    x = keras.layers.Conv2D(filters=channel,
                            kernel_size=kernel_size,
                            kernel_initializer='he_normal',
                            kernel_regularizer=keras.regularizers.l2(1e-4),
                            padding='same',
                            strides=strides
                           )(input_layer)
    
    x = keras.layers.BatchNormalization()(x)
    
    if activation:
        x = keras.layers.Activation(activation)(x)
    
    return x

# %%
def build_resnet_block(input_layer, 
                       num_cnn=3, 
                       channel=64, 
                       block_num=0, 
                       is_50=True):
    
    x = input_layer
    
    # ResNet-50
    if is_50:
        for i in range(num_cnn):
            if i == 0:
                shortcut = conv_block(x, channel*4, (1,1), strides=2, activation=None)
                x = conv_block(x, channel, (1,1), strides=2)
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1), activation=None)
            else:
                shortcut = x
                x = conv_block(x, channel, (1,1))
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1), activation=None)
            
            x = keras.layers.Add()([x, shortcut])
            x = keras.layers.Activation('relu')(x)
    
    # ResNet-34
    else:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                shortcut = conv_block(x, channel, (1,1), strides=2, activation=None)
                x = conv_block(x, channel, (3,3), strides=2)
                x = conv_block(x, channel, (3,3), activation=None)
            else:
                shortcut = x
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel, (3,3), activation=None)
            
            x = keras.layers.Add()([x, shortcut])
            x = keras.layers.Activation('relu')(x)
    

    return x

# %%
def build_resnet(input_shape=(32,32,3),
                 num_cnn_list=[3,4,6,3],
                 channel_list=[64,128,256,512],
                 num_classes=2, 
                 is_50=True, 
                 activation='softmax',
                 name='ResNet_50'):
    
    assert len(num_cnn_list) == len(channel_list) # 모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.
    
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    
    # first layer
    x = conv_block(input_layer, 64, (7,7), strides=2)
    x = keras.layers.MaxPool2D(pool_size=(2,2), strides=2)(x)
    
    # config list들의 길이만큼 반복해서 Residual block 블록을 생성합니다.
    for block_num, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        x = build_resnet_block(x, 
                               num_cnn=num_cnn, 
                               channel=channel, 
                               block_num=block_num, 
                               is_50=is_50)
        
    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dense(num_classes, 
                           activation=activation, 
                           kernel_initializer='he_normal'
                          )(x)
    
    model = keras.Model(inputs=input_layer, outputs=x, name=name)
    
    return model

# %% [markdown]
# ## 2) ResNet-34, ResNet-50 Complete Model
# ***

# %% [markdown]
# ### ResNet-34

# %%
resnet_34 = build_resnet(input_shape=(224,224,3), is_50=False, activation='relu', name='ResNet_34')
resnet_34.summary()
# Out:
# Model: "ResNet_34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 56, 56, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['batch_normalization_4[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 56, 56, 64)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 56, 56, 64)   0           ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 128)  73856       ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  147584      ['activation_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 128)  8320        ['activation_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  activation_8 (Activation)      (None, 28, 28, 128)  0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_11[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_13[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 128)  0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['add_6[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 256)  295168      ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 256)  33024       ['activation_14[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 14, 14, 256)  0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 14, 14, 256)  0           ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['batch_normalization_20[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_18 (Activation)     (None, 14, 14, 256)  0           ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['batch_normalization_22[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 14, 14, 256)  0           ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 14, 14, 256)  0           ['batch_normalization_24[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_23[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 14, 14, 256)  0           ['batch_normalization_26[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 256)  0           ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 14, 14, 256)  0           ['batch_normalization_28[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['add_12[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 512)    1180160     ['activation_26[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 512)    131584      ['activation_26[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_29[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_31[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  activation_28 (Activation)     (None, 7, 7, 512)    0           ['add_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_29[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_33[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_33[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 7, 7, 512)    0           ['add_14[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_35[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_35[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 7, 7, 512)    0           ['add_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_32[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            1026        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,311,234
# Trainable params: 21,294,210
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %% [markdown]
# ### ResNet-50

# %%
resnet_50 = build_resnet(input_shape=(224,224,3), is_50=True, activation='relu', name='ResNet_50')
resnet_50.summary()
# Out:
# Model: "ResNet_50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_36 (Conv2D)             (None, 112, 112, 64  9472        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 112, 112, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 112, 112, 64  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['activation_33[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 28, 28, 64)   4160        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 28, 28, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 28, 28, 64)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 28, 28, 64)   36928       ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 28, 28, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 28, 28, 64)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 28, 28, 256)  16640       ['activation_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 28, 28, 256)  16640       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_37[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 28, 28, 256)  0           ['batch_normalization_40[0][0]',
#                                                                   'batch_normalization_37[0][0]']
#
#  activation_36 (Activation)     (None, 28, 28, 256)  0           ['add_16[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 28, 28, 64)   16448       ['activation_36[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 28, 28, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 28, 28, 64)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 28, 28, 64)   36928       ['activation_37[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 28, 28, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 28, 28, 64)   0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 28, 28, 256)  16640       ['activation_38[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_43[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 28, 28, 256)  0           ['batch_normalization_43[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 28, 28, 256)  0           ['add_17[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 28, 28, 64)   16448       ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 28, 28, 64)  256         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 28, 28, 64)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 28, 28, 64)   36928       ['activation_40[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 28, 28, 64)  256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 28, 28, 64)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 28, 28, 256)  16640       ['activation_41[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_46[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 28, 28, 256)  0           ['batch_normalization_46[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_42 (Activation)     (None, 28, 28, 256)  0           ['add_18[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 128)  32896       ['activation_42[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 14, 14, 128)  512        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 128)  147584      ['activation_43[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 14, 14, 128)  512        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 512)  66048       ['activation_44[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 512)  131584      ['activation_42[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_47[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 14, 14, 512)  0           ['batch_normalization_50[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  activation_45 (Activation)     (None, 14, 14, 512)  0           ['add_19[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 128)  65664       ['activation_45[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 14, 14, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 128)  147584      ['activation_46[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 14, 14, 128)  512        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 512)  66048       ['activation_47[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_53[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 14, 14, 512)  0           ['batch_normalization_53[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 14, 14, 512)  0           ['add_20[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 128)  65664       ['activation_48[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 14, 14, 128)  512        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 128)  147584      ['activation_49[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 14, 14, 128)  512        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 512)  66048       ['activation_50[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_56[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 14, 14, 512)  0           ['batch_normalization_56[0][0]',
#                                                                   'activation_48[0][0]']
#
#  activation_51 (Activation)     (None, 14, 14, 512)  0           ['add_21[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 128)  65664       ['activation_51[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 14, 14, 128)  512        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 14, 14, 128)  147584      ['activation_52[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 14, 14, 128)  512        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 14, 14, 512)  66048       ['activation_53[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_59[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 14, 14, 512)  0           ['batch_normalization_59[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 14, 14, 512)  0           ['add_22[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 7, 7, 256)    131328      ['activation_54[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_55[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_56[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 7, 7, 1024)   525312      ['activation_54[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_60[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_63[0][0]',
#                                                                   'batch_normalization_60[0][0]']
#
#  activation_57 (Activation)     (None, 7, 7, 1024)   0           ['add_23[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_57[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_58[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_59[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_66[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_66[0][0]',
#                                                                   'activation_57[0][0]']
#
#  activation_60 (Activation)     (None, 7, 7, 1024)   0           ['add_24[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_60[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_61[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_62[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_69[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_69[0][0]',
#                                                                   'activation_60[0][0]']
#
#  activation_63 (Activation)     (None, 7, 7, 1024)   0           ['add_25[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_63[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_70[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_64[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_65[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_72[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_72[0][0]',
#                                                                   'activation_63[0][0]']
#
#  activation_66 (Activation)     (None, 7, 7, 1024)   0           ['add_26[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_66[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_73[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_73[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_67[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_68[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_75[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_75[0][0]',
#                                                                   'activation_66[0][0]']
#
#  activation_69 (Activation)     (None, 7, 7, 1024)   0           ['add_27[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_69[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_76[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_70[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_77[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_71[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_78[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_78[0][0]',
#                                                                   'activation_69[0][0]']
#
#  activation_72 (Activation)     (None, 7, 7, 1024)   0           ['add_28[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 4, 4, 512)    524800      ['activation_72[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_73[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 4, 4, 2048)   1050624     ['activation_74[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 4, 4, 2048)   2099200     ['activation_72[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 4, 4, 2048)  8192        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 4, 4, 2048)  8192        ['conv2d_79[0][0]']
#  ormalization)
#
#  add_29 (Add)                   (None, 4, 4, 2048)   0           ['batch_normalization_82[0][0]',
#                                                                   'batch_normalization_79[0][0]']
#
#  activation_75 (Activation)     (None, 4, 4, 2048)   0           ['add_29[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 4, 4, 512)    1049088     ['activation_75[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_83[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_83[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_76[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_84[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 4, 4, 2048)   1050624     ['activation_77[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 4, 4, 2048)  8192        ['conv2d_85[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 4, 4, 2048)   0           ['batch_normalization_85[0][0]',
#                                                                   'activation_75[0][0]']
#
#  activation_78 (Activation)     (None, 4, 4, 2048)   0           ['add_30[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 4, 4, 512)    1049088     ['activation_78[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_79[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_87[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_87[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 4, 4, 2048)   1050624     ['activation_80[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 4, 4, 2048)  8192        ['conv2d_88[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 4, 4, 2048)   0           ['batch_normalization_88[0][0]',
#                                                                   'activation_78[0][0]']
#
#  activation_81 (Activation)     (None, 4, 4, 2048)   0           ['add_31[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['activation_81[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 2)            4098        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3) 일반 네트워크(plain network) 만들기
# ***

# %%
def build_plain_block(input_layer, 
                      num_cnn=3, 
                      channel=64, 
                      block_num=0, 
                      is_50=True):
    
    x = input_layer
    
    # plain-50
    if is_50:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                x = conv_block(x, channel, (1,1), strides=2)
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1))
            else:
                x = conv_block(x, channel, (1,1))
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1))
    
    # plain-34
    else:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                x = conv_block(x, channel, (3,3), strides=2)
                x = conv_block(x, channel, (3,3))
            else:
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel, (3,3))

    return x

# %%
def build_plain(input_shape=(32,32,3), 
                   num_cnn_list=[3,4,6,3],
                   channel_list=[64,128,256,512],
                   num_classes=10,
                   is_50=True, 
                   activation='softmax',
                   name='Plain_50'):
    
    assert len(num_cnn_list) == len(channel_list)
    
    input_layer = keras.layers.Input(shape=input_shape)
    
    # first layer
    x = conv_block(input_layer, 64, (7,7), strides=2)
    x = keras.layers.MaxPool2D(pool_size=(2,2), strides=2)(x)
    
    # config list들의 길이만큼 반복해서 plain block 블록을 생성합니다.
    for block_num, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        x = build_plain_block(x, 
                              num_cnn=num_cnn, 
                              channel=channel,
                              block_num=block_num,
                              is_50=is_50)
    
    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dense(num_classes, 
                           activation=activation,
                           kernel_initializer='he_normal'
                          )(x)
    
    model = keras.Model(inputs=input_layer, outputs=x, name=name)
    
    return model

# %% [markdown]
# ### Plain-34

# %%
plain_34 = build_plain(input_shape=(224,224,3), is_50=False, activation='relu', name='Plain_34')
plain_34.summary()
# Out:
# Model: "Plain_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_89 (Conv2D)          (None, 112, 112, 64)      9472
#
#  batch_normalization_89 (Bat  (None, 112, 112, 64)     256
#  chNormalization)
#
#  activation_82 (Activation)  (None, 112, 112, 64)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_90 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_90 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_83 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_91 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_91 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_84 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_92 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_92 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_85 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_93 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_93 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_86 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_94 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_94 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_87 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_95 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_95 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_88 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_96 (Conv2D)          (None, 28, 28, 128)       73856
#
#  batch_normalization_96 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  activation_89 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_97 (Conv2D)          (None, 28, 28, 128)       147584
#
#  batch_normalization_97 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  activation_90 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_98 (Conv2D)          (None, 28, 28, 128)       147584
#
#  batch_normalization_98 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  activation_91 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_99 (Conv2D)          (None, 28, 28, 128)       147584
#
#  batch_normalization_99 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  activation_92 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_100 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_100 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_93 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_101 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_101 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_102 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_102 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_103 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_103 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_104 (Conv2D)         (None, 14, 14, 256)       295168
#
#  batch_normalization_104 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 14, 14, 256)       0
#
#  conv2d_105 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_105 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 14, 14, 256)       0
#
#  conv2d_106 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_106 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_99 (Activation)  (None, 14, 14, 256)       0
#
#  conv2d_107 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_107 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_100 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_108 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_108 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_101 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_109 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_109 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_102 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_110 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_110 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_103 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_111 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_111 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_104 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_112 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_112 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_105 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_113 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_113 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_106 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_114 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_114 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_107 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_115 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_115 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_108 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_116 (Conv2D)         (None, 7, 7, 512)         1180160
#
#  batch_normalization_116 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_109 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_117 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_117 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_110 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_118 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_118 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_111 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_119 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_119 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_112 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_120 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_120 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_113 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_121 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_121 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_114 (Activation)  (None, 7, 7, 512)        0
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 21,138,826
# Trainable params: 21,123,594
# Non-trainable params: 15,232
# _________________________________________________________________

# %%
plain_50 = build_plain(input_shape=(224,224,3), is_50=True, activation='relu', name='Plain_50')
plain_50.summary()
# Out:
# Model: "Plain_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_122 (Conv2D)         (None, 112, 112, 64)      9472
#
#  batch_normalization_122 (Ba  (None, 112, 112, 64)     256
#  tchNormalization)
#
#  activation_115 (Activation)  (None, 112, 112, 64)     0
#
#  max_pooling2d_3 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_123 (Conv2D)         (None, 56, 56, 64)        4160
#
#  batch_normalization_123 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_116 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_124 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_124 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_117 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_125 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_125 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_118 (Activation)  (None, 56, 56, 256)      0
#
#  conv2d_126 (Conv2D)         (None, 56, 56, 64)        16448
#
#  batch_normalization_126 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_119 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_127 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_127 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_120 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_128 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_128 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_121 (Activation)  (None, 56, 56, 256)      0
#
#  conv2d_129 (Conv2D)         (None, 56, 56, 64)        16448
#
#  batch_normalization_129 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_122 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_130 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_130 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_123 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_131 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_131 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_124 (Activation)  (None, 56, 56, 256)      0
#
#  conv2d_132 (Conv2D)         (None, 28, 28, 128)       32896
#
#  batch_normalization_132 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_125 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_133 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_133 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_126 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_134 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_134 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_127 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_135 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_135 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_128 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_136 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_136 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_129 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_137 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_137 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_130 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_138 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_138 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_131 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_139 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_139 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_132 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_140 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_140 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_133 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_141 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_141 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_134 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_142 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_142 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_135 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_143 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_143 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_136 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_144 (Conv2D)         (None, 14, 14, 256)       131328
#
#  batch_normalization_144 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_137 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_145 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_145 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_138 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_146 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_146 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_139 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_147 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_147 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_140 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_148 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_148 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_141 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_149 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_149 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_142 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_150 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_150 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_143 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_151 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_151 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_144 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_152 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_152 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_145 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_153 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_153 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_146 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_154 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_154 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_147 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_155 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_155 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_148 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_156 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_156 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_149 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_157 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_157 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_150 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_158 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_158 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_151 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_159 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_159 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_152 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_160 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_160 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_153 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_161 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_161 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_154 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_162 (Conv2D)         (None, 7, 7, 512)         524800
#
#  batch_normalization_162 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_155 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_163 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_163 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_156 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_164 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_164 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_157 (Activation)  (None, 7, 7, 2048)       0
#
#  conv2d_165 (Conv2D)         (None, 7, 7, 512)         1049088
#
#  batch_normalization_165 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_158 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_166 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_166 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_159 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_167 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_167 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_160 (Activation)  (None, 7, 7, 2048)       0
#
#  conv2d_168 (Conv2D)         (None, 7, 7, 512)         1049088
#
#  batch_normalization_168 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_161 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_169 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_169 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_162 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_170 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_170 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_163 (Activation)  (None, 7, 7, 2048)       0
#
#  global_average_pooling2d_3   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 10)                20490
#
# =================================================================
# Total params: 20,820,106
# Trainable params: 20,774,666
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ## 4) ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34
# ***
# * 모델 학습
# * 비교

# %%
BATCH_SIZE = 32
EPOCH = 10

# %%
# 데이터 정의

ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %% [markdown]
# #### Plain-34

# %%
# Plain-34 학습


plain_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain_34 = plain_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 581/581 [==============================] - 100s 129ms/step - loss: 4.0563 - accuracy: 0.4964 - val_loss: 3.8458 - val_accuracy: 0.4892
# Epoch 2/10
# 581/581 [==============================] - 71s 123ms/step - loss: 3.8213 - accuracy: 0.5031 - val_loss: 3.8644 - val_accuracy: 0.4830
# Epoch 3/10
# 581/581 [==============================] - 71s 122ms/step - loss: 3.8178 - accuracy: 0.5045 - val_loss: 3.8414 - val_accuracy: 0.4972
# Epoch 4/10
# 581/581 [==============================] - 71s 122ms/step - loss: 3.8156 - accuracy: 0.5031 - val_loss: 3.8125 - val_accuracy: 0.4840
# Epoch 5/10
# 581/581 [==============================] - 71s 122ms/step - loss: 3.8112 - accuracy: 0.5044 - val_loss: 3.8090 - val_accuracy: 0.4900
# Epoch 6/10
# 581/581 [==============================] - 71s 122ms/step - loss: 3.8073 - accuracy: 0.5040 - val_loss: 3.8055 - val_accuracy: 0.4877
# Epoch 7/10
# 581/581 [==============================] - 71s 122ms/step - loss: 3.8038 - accuracy: 0.5037 - val_loss: 3.8020 - val_accuracy: 0.4911
# Epoch 8/10
# 581/581 [==============================] - 71s 122ms/step - loss: 3.8003 - accuracy: 0.5056 - val_loss: 3.7985 - val_accuracy: 0.4885
# Epoch 9/10
# 581/581 [==============================] - 71s 122ms/step - loss: 3.7968 - accuracy: 0.5019 - val_loss: 3.7951 - val_accuracy: 0.4950
# Epoch 10/10
# 581/581 [==============================] - 71s 123ms/step - loss: 3.7933 - accuracy: 0.5040 - val_loss: 3.7916 - val_accuracy: 0.4848

# %% [markdown]
# #### ResNet-34

# %%
# ResNet-34 학습


resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_resnet_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 581/581 [==============================] - 95s 130ms/step - loss: 2.3544 - accuracy: 0.5031 - val_loss: 2.3518 - val_accuracy: 0.4888
# Epoch 2/10
# 581/581 [==============================] - 74s 127ms/step - loss: 2.3499 - accuracy: 0.5031 - val_loss: 2.3479 - val_accuracy: 0.4890
# Epoch 3/10
# 581/581 [==============================] - 74s 127ms/step - loss: 2.3460 - accuracy: 0.5067 - val_loss: 2.3441 - val_accuracy: 0.4959
# Epoch 4/10
# 581/581 [==============================] - 74s 127ms/step - loss: 2.3422 - accuracy: 0.5035 - val_loss: 2.3403 - val_accuracy: 0.4898
# Epoch 5/10
# 581/581 [==============================] - 73s 127ms/step - loss: 2.3383 - accuracy: 0.5033 - val_loss: 2.3364 - val_accuracy: 0.4866
# Epoch 6/10
# 581/581 [==============================] - 74s 127ms/step - loss: 2.3345 - accuracy: 0.5030 - val_loss: 2.3326 - val_accuracy: 0.4976
# Epoch 7/10
# 581/581 [==============================] - 79s 137ms/step - loss: 2.3307 - accuracy: 0.5072 - val_loss: 2.3288 - val_accuracy: 0.4905
# Epoch 8/10
# 581/581 [==============================] - 78s 134ms/step - loss: 2.3269 - accuracy: 0.5044 - val_loss: 2.3250 - val_accuracy: 0.4870
# Epoch 9/10
# 581/581 [==============================] - 76s 131ms/step - loss: 2.3231 - accuracy: 0.5008 - val_loss: 2.3212 - val_accuracy: 0.4864
# Epoch 10/10
# 581/581 [==============================] - 77s 133ms/step - loss: 2.3193 - accuracy: 0.5040 - val_loss: 2.3175 - val_accuracy: 0.4877

# %% [markdown]
# #### Plain-50

# %%
# Plain-50 학습


plain_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain_50 = plain_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 581/581 [==============================] - 120s 176ms/step - loss: 5.2478 - accuracy: 0.5426 - val_loss: 5.2273 - val_accuracy: 0.5293
# Epoch 2/10
# 581/581 [==============================] - 111s 191ms/step - loss: 5.2241 - accuracy: 0.5368 - val_loss: 5.2169 - val_accuracy: 0.5472
# Epoch 3/10
# 581/581 [==============================] - 99s 171ms/step - loss: 5.2608 - accuracy: 0.5442 - val_loss: 5.2187 - val_accuracy: 0.5357
# Epoch 4/10
# 581/581 [==============================] - 99s 171ms/step - loss: 5.2142 - accuracy: 0.5403 - val_loss: 5.2123 - val_accuracy: 0.5156
# Epoch 5/10
# 581/581 [==============================] - 99s 171ms/step - loss: 5.2092 - accuracy: 0.5415 - val_loss: 5.1986 - val_accuracy: 0.5390
# Epoch 6/10
# 581/581 [==============================] - 100s 173ms/step - loss: 5.1938 - accuracy: 0.5261 - val_loss: 5.1851 - val_accuracy: 0.5470
# Epoch 7/10
# 581/581 [==============================] - 100s 173ms/step - loss: 5.2411 - accuracy: 0.5507 - val_loss: 5.1767 - val_accuracy: 0.5636
# Epoch 8/10
# 581/581 [==============================] - 101s 174ms/step - loss: 5.1872 - accuracy: 0.5412 - val_loss: 5.1788 - val_accuracy: 0.5528
# Epoch 9/10
# 581/581 [==============================] - 100s 173ms/step - loss: 5.1786 - accuracy: 0.5178 - val_loss: 5.1722 - val_accuracy: 0.5301
# Epoch 10/10
# 581/581 [==============================] - 100s 172ms/step - loss: 5.1754 - accuracy: 0.5392 - val_loss: 5.1813 - val_accuracy: 0.5318

# %% [markdown]
# #### ResNet-50

# %%
# ResNet-50 학습


resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_resnet_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 581/581 [==============================] - 86s 114ms/step - loss: 6.0052 - accuracy: 0.5045 - val_loss: 5.9963 - val_accuracy: 0.4829
# Epoch 2/10
# 581/581 [==============================] - 65s 111ms/step - loss: 5.9901 - accuracy: 0.5048 - val_loss: 5.9840 - val_accuracy: 0.4814
# Epoch 3/10
# 581/581 [==============================] - 65s 111ms/step - loss: 5.9778 - accuracy: 0.5039 - val_loss: 5.9717 - val_accuracy: 0.4959
# Epoch 4/10
# 581/581 [==============================] - 65s 112ms/step - loss: 5.9656 - accuracy: 0.5041 - val_loss: 5.9657 - val_accuracy: 0.4978
# Epoch 5/10
# 581/581 [==============================] - 65s 112ms/step - loss: 5.9540 - accuracy: 0.5051 - val_loss: 5.9472 - val_accuracy: 0.4998
# Epoch 6/10
# 581/581 [==============================] - 65s 113ms/step - loss: 5.9411 - accuracy: 0.5017 - val_loss: 5.9350 - val_accuracy: 0.4886
# Epoch 7/10
# 581/581 [==============================] - 66s 113ms/step - loss: 5.9290 - accuracy: 0.5032 - val_loss: 5.9229 - val_accuracy: 0.4836
# Epoch 8/10
# 581/581 [==============================] - 65s 113ms/step - loss: 5.9168 - accuracy: 0.5017 - val_loss: 5.9107 - val_accuracy: 0.4885
# Epoch 9/10
# 581/581 [==============================] - 65s 112ms/step - loss: 5.9047 - accuracy: 0.5063 - val_loss: 5.8986 - val_accuracy: 0.4946
# Epoch 10/10
# 581/581 [==============================] - 65s 112ms/step - loss: 5.8926 - accuracy: 0.5067 - val_loss: 5.8865 - val_accuracy: 0.4881

# %% [markdown]
# ### ResNet-34 vs Plain-34
# * Loss 비교
# * Accuracy 비교

# %% [markdown]
# ResNet-34 & Plain-34 Validation Loss

# %%
import matplotlib.pyplot as plt


# ResNet-34, Plain-34 Validation Loss 시각화

plt.plot(history_resnet_34.history['val_loss'], 'r')
plt.plot(history_plain_34.history['val_loss'], 'b')
plt.title('ResNet-34 & Plain-34 Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'plain_34'], loc='upper left')
plt.show()

# %% [markdown]
# ResNet-34 & Plain-34 Validation Accuracy

# %%
# ResNet-34, Plain-34 Validation Accuracy 시각화

plt.plot(history_resnet_34.history['val_accuracy'], 'r')
plt.plot(history_plain_34.history['val_accuracy'], 'b')
plt.title('ResNet-34 & Plain-34 Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'plain_34'], loc='upper left')
plt.show()

# %% [markdown]
# ### ResNet-50 vs Plain-50
# * Loss 비교
# * Accuracy 비교

# %% [markdown]
# ResNet-50 & Plain-50 Validation Loss

# %%
# ResNet-50, Plain-50 Validation Loss 시각화

plt.plot(history_resnet_50.history['val_loss'], 'r')
plt.plot(history_plain_50.history['val_loss'], 'b')
plt.title('ResNet-50 & Plain-50 Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'plain_50'], loc='upper left')
plt.show()

# %% [markdown]
# ResNet-50 & Plain-50 Validation Accuracy

# %%
# ResNet-50, Plain-50 Validation Accuracy 시각화

plt.plot(history_resnet_50.history['val_accuracy'], 'r')
plt.plot(history_plain_50.history['val_accuracy'], 'b')
plt.title('ResNet-50 & Plain-50 Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'plain_50'], loc='upper left')
plt.show()

# %% [markdown]
# ResNet-34 & Plain-34 & ResNet-50 & Plain-50 Validation Loss

# %%
plt.plot(history_resnet_34.history['val_loss'], 'r')
plt.plot(history_resnet_50.history['val_loss'], 'b')
plt.plot(history_plain_34.history['val_loss'], 'y')
plt.plot(history_plain_50.history['val_loss'], 'g')
plt.title('Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet_34','ResNet_50','ResNet_34_Plain','ResNet_50_Plain'], loc='upper left')
plt.show()

# %% [markdown]
# ResNet-34 & Plain-34 & ResNet-50 & Plain-50 Validation Accuracy

# %%
plt.plot(history_resnet_34.history['val_accuracy'], 'r')
plt.plot(history_resnet_50.history['val_accuracy'], 'b')
plt.plot(history_plain_34.history['val_accuracy'], 'y')
plt.plot(history_plain_50.history['val_accuracy'], 'g')
plt.title('Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet_34','ResNet_50','ResNet_34_Plain','ResNet_50_Plain'], loc='upper left')
plt.show()
